# %% [markdown]
# # 第10章: 機械翻訳
# 本章では，日本語と英語の翻訳コーパスである[京都フリー翻訳タスク (KFTT)](http://www.phontron.com/kftt/index-ja.html)を用い，ニューラル機械翻訳モデルを構築する．ニューラル機械翻訳モデルの構築には，[fairseq](https://github.com/pytorch/fairseq)，[Hugging Face Transformers](https://github.com/huggingface/transformers)，[OpenNMT-py](https://github.com/OpenNMT/OpenNMT-py)などの既存のツールを活用せよ．

# %% [markdown]
# ## 90. データの準備
# 機械翻訳のデータセットをダウンロードせよ．訓練データ，開発データ，評価データを整形し，必要に応じてトークン化などの前処理を行うこと．ただし，この段階ではトークンの単位として形態素（日本語）および単語（英語）を採用せよ．

# %% [markdown]
# GPUの使用制限がかかるので，データの永続化をする
# （ドライブに作業フォルダを保存する）

# %%
# 作業用フォルダの作成
from google.colab import drive 
drive.mount('/content/drive')
# !mkdir -p '/content/drive/My Drive/work/'
# %cd '/content/drive/My Drive/work/'
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/work

# %%
## データセットダウンロード
# !wget http://www.phontron.com/kftt/download/kftt-data-1.0.tar.gz
# Out:
# --2021-07-19 12:26:33--  http://www.phontron.com/kftt/download/kftt-data-1.0.tar.gz
# Resolving www.phontron.com (www.phontron.com)... 208.113.196.149
# Connecting to www.phontron.com (www.phontron.com)|208.113.196.149|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99246893 (95M) [application/gzip]
# Saving to: ‘kftt-data-1.0.tar.gz’
#
# kftt-data-1.0.tar.g 100%[===================>]  94.65M  67.3MB/s    in 1.4s
#
# 2021-07-19 12:26:34 (67.3 MB/s) - ‘kftt-data-1.0.tar.gz’ saved [99246893/99246893]

# %%
# !gunzip kftt-data-1.0.tar.gz
# Out:
# gzip: kftt-data-1.0.tar.gz: No such file or directory

# %%
# !tar -xvf kftt-data-1.0.tar
# Out:
# tar: kftt-data-1.0.tar: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
# !head -10 ./kftt-data-1.0/data/tok/kyoto-train.en
# Out:
# Known as Sesshu ( 1420 - 1506 ) , he was an ink painter and Zen monk active in the Muromachi period in the latter half of the 15th century , and was called a master painter .
# He revolutionized the Japanese ink painting .
# He was given the posthumous name " Toyo " or " Sesshu ( 拙宗 ) . "
# Born in Bicchu Province , he moved to Suo Province after entering SShokoku-ji Temple in Kyoto .
# Later he accompanied a mission to Ming Dynasty China and learned Chinese ink painting .
# His works were many , including not only Chinese-style landscape paintings , but also portraits and pictures of flowers and birds .
# His bold compositions and strong brush strokes constituted an extremely distinctive style .
# 6 of his extant works are designated national treasures . Indeed , he is considered to be extraordinary among Japanese painters .
# For this reason , there are a great many artworks that are attributed to him , such as folding screens with pictures of flowers and that birds are painted on them .
# There are many works that even experts cannot agree if they are really his work or not .

# %%
# !head -10 ./kftt-data-1.0/data/tok/kyoto-train.ja
# Out:
# 雪舟 （ せっしゅう 、 1420 年 （ 応永 27 年 ） - 1506 年 （ 永正 3 年 ） ） は 号 で 、 15 世紀 後半 室町 時代 に 活躍 し た 水墨 画 家 ・ 禅僧 で 、 画聖 と も 称え られ る 。
# 日本 の 水墨 画 を 一変 さ せ た 。
# 諱 は 「 等楊 （ とうよう ） 」 、 もしくは 「 拙宗 （ せっしゅう ） 」 と 号 し た 。
# 備中 国 に 生まれ 、 京都 ・ 相国 寺 に 入 っ て から 周防 国 に 移 る 。
# その 後 遣明 使 に 随行 し て 中国 （ 明 ） に 渡 っ て 中国 の 水墨 画 を 学 ん だ 。
# 作品 は 数 多 く 、 中国 風 の 山水 画 だけ で な く 人物 画 や 花鳥 画 も よ く し た 。
# 大胆 な 構図 と 力強 い 筆線 は 非常 に 個性 的 な 画風 を 作り出 し て い る 。
# 現存 する 作品 の うち 6 点 が 国宝 に 指定 さ れ て お り 、 日本 の 画家 の なか で も 別格 の 評価 を 受け て い る と いえ る 。
# この ため 、 花鳥 図 屏風 など に 「 伝 雪舟 筆 」 さ れ る 作品 は 大変 多 い 。
# 真筆 で あ る か 専門 家 の 間 で も 意見 の 分かれ る もの も 多々 あ る 。

# %% [markdown]
# ### 前処理

# %% [markdown]
# ### どうやら，[fairseq](https://github.com/pytorch/fairseq)が便利らしい．
# コマンドを打つだけで，学習や予測ができるので

# %% [markdown]
# ### fairseqとは
# Facebookの人工知能研究チームが開発している，機械翻訳用のフレームワークです．Facebookが開発元ということもあり，Pytorchがベースになっています．
# 最近はHuggingfaceのTransformersが人気でTransformerモデルを扱うならPytorchを使用していたため，こちらをフレームワークとして選びました．
# その他の機械翻訳フレームワークとしては，MarianNMT，OpenNMT（こちらもPytorchベース）などがあります．基本的な機能はどのフレームワークも大差ない印象ですが，論文実装のコードはfairseqが選ばれている場合が多いらしいです．

# %%
## fairseqのインストール
# !pip install fairseq
# Out:
# Collecting fairseq
#   Downloading fairseq-0.10.2-cp37-cp37m-manylinux1_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 4.9 MB/s
# Collecting hydra-core
#   Downloading hydra_core-1.1.0-py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 19.5 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fairseq) (1.19.5)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from fairseq) (0.29.23)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: cffi in /usr/local/lib/python3.7/dist-packages (from fairseq) (1.14.6)
# Collecting sacrebleu>=1.4.12
#   Downloading sacrebleu-1.5.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.2 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from fairseq) (4.41.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from fairseq) (1.9.0+cu102)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from fairseq) (2019.12.20)
# Collecting portalocker==2.0.0
#   Downloading portalocker-2.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi->fairseq) (2.20)
# Collecting antlr4-python3-runtime==4.8
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      |████████████████████████████████| 112 kB 19.5 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core->fairseq) (5.2.0)
# Collecting omegaconf==2.1.*
#   Downloading omegaconf-2.1.0-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 2.8 MB/s
# Collecting PyYAML>=5.1.*
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 19.7 MB/s
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->hydra-core->fairseq) (3.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->fairseq) (3.7.4.3)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141229 sha256=3a3a0bf9fe8c749bfde5d61f355aa5f62eb0481be5ad9e051302118fa6c44773
#   Stored in directory: /root/.cache/pip/wheels/ca/33/b7/336836125fc9bb4ceaa4376d8abca10ca8bc84ddc824baea6c
# Successfully built antlr4-python3-runtime
# Installing collected packages: PyYAML, antlr4-python3-runtime, portalocker, omegaconf, sacrebleu, hydra-core, dataclasses, fairseq
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-5.4.1 antlr4-python3-runtime-4.8 dataclasses-0.6 fairseq-0.10.2 hydra-core-1.1.0 omegaconf-2.1.0 portalocker-2.0.0 sacrebleu-1.5.1

# %%
import os

# %%
# !mkdir ./data-bin
# !mkdir ./data-bin/kftt.ja-en

# %% [markdown]
# fairseq-preprocessはテキストデータをバイナリ化して保存します。今回はすでにspaceでtokenizeされているのでspaceを使いました。

# %%
# !fairseq-preprocess -s ja -t en \
    --trainpref  /content/kftt-data-1.0/data/tok/kyoto-train \
    --validpref  /content/kftt-data-1.0/data/tok/kyoto-dev \
    --testpref /content/kftt-data-1.0/data/tok/kyoto-test \
    --destdir data91  \
    --thresholdsrc 5 \
    --thresholdtgt 5 \
    --workers 20
# Out:
# 2021-07-19 12:33:26 | INFO | fairseq_cli.preprocess | Namespace(align_suffix=None, alignfile=None, all_gather_list_size=16384, bf16=False, bpe=None, checkpoint_shard_count=1, checkpoint_suffix='', cpu=False, criterion='cross_entropy', dataset_impl='mmap', destdir='data91', empty_cache_freq=0, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, joined_dictionary=False, log_format=None, log_interval=100, lr_scheduler='fixed', memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, model_parallel_size=1, no_progress_bar=False, nwordssrc=-1, nwordstgt=-1, only_source=False, optimizer=None, padding_factor=8, profile=False, quantization_config_path=None, scoring='bleu', seed=1, source_lang='ja', srcdict=None, target_lang='en', task='translation', tensorboard_logdir=None, testpref='/content/kftt-data-1.0/data/tok/kyoto-test', tgtdict=None, threshold_loss_scale=None, thresholdsrc=5, thresholdtgt=5, tokenizer=None, tpu=False, trainpref='/content/kftt-data-1.0/data/tok/kyoto-train', user_dir=None, validpref='/content/kftt-data-1.0/data/tok/kyoto-dev', workers=20)
# 2021-07-19 12:34:54 | INFO | fairseq_cli.preprocess | [ja] Dictionary: 51584 types
# 2021-07-19 12:36:29 | INFO | fairseq_cli.preprocess | [ja] /content/kftt-data-1.0/data/tok/kyoto-train.ja: 440288 sents, 12359715 tokens, 1.26% replaced by <unk>
# 2021-07-19 12:36:29 | INFO | fairseq_cli.preprocess | [ja] Dictionary: 51584 types
# 2021-07-19 12:36:30 | INFO | fairseq_cli.preprocess | [ja] /content/kftt-data-1.0/data/tok/kyoto-dev.ja: 1166 sents, 28010 tokens, 1.3% replaced by <unk>
# 2021-07-19 12:36:30 | INFO | fairseq_cli.preprocess | [ja] Dictionary: 51584 types
# 2021-07-19 12:36:32 | INFO | fairseq_cli.preprocess | [ja] /content/kftt-data-1.0/data/tok/kyoto-test.ja: 1160 sents, 29638 tokens, 1.4% replaced by <unk>
# 2021-07-19 12:36:32 | INFO | fairseq_cli.preprocess | [en] Dictionary: 58552 types
# 2021-07-19 12:37:40 | INFO | fairseq_cli.preprocess | [en] /content/kftt-data-1.0/data/tok/kyoto-train.en: 440288 sents, 11981667 tokens, 2.07% replaced by <unk>
# 2021-07-19 12:37:40 | INFO | fairseq_cli.preprocess | [en] Dictionary: 58552 types
# 2021-07-19 12:37:42 | INFO | fairseq_cli.preprocess | [en] /content/kftt-data-1.0/data/tok/kyoto-dev.en: 1166 sents, 25475 tokens, 3.19% replaced by <unk>
# 2021-07-19 12:37:42 | INFO | fairseq_cli.preprocess | [en] Dictionary: 58552 types
# 2021-07-19 12:37:43 | INFO | fairseq_cli.preprocess | [en] /content/kftt-data-1.0/data/tok/kyoto-test.en: 1160 sents, 27894 tokens, 2.88% replaced by <unk>
# 2021-07-19 12:37:43 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to data91

# %%
# !ls kftt-data-1.0/data/tok/
# Out:
# kyoto-dev.en  kyoto-test.en  kyoto-train.cln.en  kyoto-train.en  kyoto-tune.en
# kyoto-dev.ja  kyoto-test.ja  kyoto-train.cln.ja  kyoto-train.ja  kyoto-tune.ja

# %% [markdown]
# ## 91. 機械翻訳モデルの訓練
# 90で準備したデータを用いて，ニューラル機械翻訳のモデルを学習せよ（ニューラルネットワークのモデルはTransformerやLSTMなど適当に選んでよい）．

# %% [markdown]
# 学習の設定は以下に箇条書きした．
# （ハイパーパラメータは後にチューニングする）
#
# *   モデル：LSTM
# *   optimizer : adam
# *   学習率：1e-5
# *   ドロップアウト：0.3
# *   最大エポック数：5
# *   損失：交差エントロピー

# %%
os.system("mkdir checkpoints")
os.system("mkdir checkpoints/kftt.ja-en")
# Out:
# 256

# %%
# !pip install sacremoses
# Out:
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (0.0.45)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sacremoses) (4.41.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses) (1.15.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacremoses) (2019.12.20)

# %%
# !fairseq-train data91 \
    --save-dir checkpoints/kftt.ja-en/ \
    --arch lstm --share-decoder-input-output-embed \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --max-epoch 5 \
    --eval-bleu \
    --eval-bleu-detok moses \
    --eval-bleu-remove-bpe \
    --eval-bleu-print-samples \
    --best-checkpoint-metric bleu --maximize-best-checkpoint-metric

## --eval-bleu-detok moses \ トークン化解除
##　--eval-bleu-remove-bpe \　BLEUを計算する前にBPEを削除する
##　--eval-bleu-print-samples \　検証中にサンプルした世代を出力する
##　--best-checkpoint-metric bleu \　最良のチェックポイントを保存するために使用するメトリック=bleuに指定
##　--maximize-best-checkpoint-metric
# Out:
# 2021-07-19 07:33:18 | INFO | fairseq_cli.train | Namespace(adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_softmax_cutoff='10000,50000,200000', all_gather_list_size=16384, arch='lstm', batch_size=None, batch_size_valid=None, best_checkpoint_metric='bleu', bf16=False, bpe=None, broadcast_buffers=False, bucket_cap_mb=25, checkpoint_shard_count=1, checkpoint_suffix='', clip_norm=0.0, cpu=False, criterion='label_smoothed_cross_entropy', curriculum=0, data='data91', data_buffer_size=10, dataset_impl=None, ddp_backend='c10d', decoder_attention='1', decoder_dropout_in=0.3, decoder_dropout_out=0.3, decoder_embed_dim=512, decoder_embed_path=None, decoder_freeze_embed=False, decoder_hidden_size=512, decoder_layers=1, decoder_out_embed_dim=512, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_num_procs=1, distributed_port=-1, distributed_rank=0, distributed_world_size=1, distributed_wrapper='DDP', dropout=0.3, empty_cache_freq=0, encoder_bidirectional=False, encoder_dropout_in=0.3, encoder_dropout_out=0.3, encoder_embed_dim=512, encoder_embed_path=None, encoder_freeze_embed=False, encoder_hidden_size=512, encoder_layers=1, eval_bleu=True, eval_bleu_args=None, eval_bleu_detok='moses', eval_bleu_detok_args=None, eval_bleu_print_samples=True, eval_bleu_remove_bpe='@@ ', eval_tokenized_bleu=False, fast_stat_sync=False, find_unused_parameters=False, finetune_from_model=None, fix_batches_to_gpus=False, fixed_validation_seed=None, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', ignore_prefix_size=0, keep_best_checkpoints=-1, keep_interval_updates=-1, keep_last_epochs=-1, label_smoothing=0.1, left_pad_source='True', left_pad_target='False', load_alignments=False, localsgd_frequency=3, log_format=None, log_interval=100, lr=[0.0005], lr_scheduler='inverse_sqrt', max_epoch=5, max_source_positions=1024, max_target_positions=1024, max_tokens=4096, max_tokens_valid=4096, max_update=0, maximize_best_checkpoint_metric=True, memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=-1.0, model_parallel_size=1, no_epoch_checkpoints=False, no_last_checkpoints=False, no_progress_bar=False, no_save=False, no_save_optimizer_state=False, no_seed_provided=False, nprocs_per_node=1, num_batch_buckets=0, num_shards=1, num_workers=1, optimizer='adam', optimizer_overrides='{}', patience=-1, pipeline_balance=None, pipeline_checkpoint='never', pipeline_chunks=0, pipeline_decoder_balance=None, pipeline_decoder_devices=None, pipeline_devices=None, pipeline_encoder_balance=None, pipeline_encoder_devices=None, pipeline_model_parallel=False, profile=False, quantization_config_path=None, report_accuracy=False, required_batch_size_multiple=8, required_seq_len_multiple=1, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='checkpoints/kftt.ja-en/', save_interval=1, save_interval_updates=0, scoring='bleu', seed=1, sentence_avg=False, shard_id=0, share_all_embeddings=False, share_decoder_input_output_embed=True, skip_invalid_size_inputs_valid_test=False, slowmo_algorithm='LocalSGD', slowmo_momentum=None, source_lang=None, stop_time_hours=0, target_lang=None, task='translation', tensorboard_logdir=None, threshold_loss_scale=None, tokenizer=None, tpu=False, train_subset='train', truncate_source=False, update_freq=[1], upsample_primary=1, use_bmuf=False, use_old_adam=False, user_dir=None, valid_subset='valid', validate_after_updates=0, validate_interval=1, validate_interval_updates=0, warmup_init_lr=-1, warmup_updates=4000, weight_decay=0.0001, zero_sharding='none')
# 2021-07-19 07:33:18 | INFO | fairseq.tasks.translation | [ja] dictionary: 51584 types
# 2021-07-19 07:33:18 | INFO | fairseq.tasks.translation | [en] dictionary: 58552 types
# 2021-07-19 07:33:18 | INFO | fairseq.data.data_utils | loaded 1166 examples from: data91/valid.ja-en.ja
# 2021-07-19 07:33:18 | INFO | fairseq.data.data_utils | loaded 1166 examples from: data91/valid.ja-en.en
# 2021-07-19 07:33:18 | INFO | fairseq.tasks.translation | data91 valid ja-en 1166 examples
# 2021-07-19 07:33:19 | INFO | fairseq_cli.train | LSTMModel(
#   (encoder): LSTMEncoder(
#     (dropout_in_module): FairseqDropout()
#     (dropout_out_module): FairseqDropout()
#     (embed_tokens): Embedding(51584, 512, padding_idx=1)
#     (lstm): LSTM(512, 512)
#   )
#   (decoder): LSTMDecoder(
#     (dropout_in_module): FairseqDropout()
#     (dropout_out_module): FairseqDropout()
#     (embed_tokens): Embedding(58552, 512, padding_idx=1)
#     (layers): ModuleList(
#       (0): LSTMCell(1024, 512)
#     )
#     (attention): AttentionLayer(
#       (input_proj): Linear(in_features=512, out_features=512, bias=False)
#       (output_proj): Linear(in_features=1024, out_features=512, bias=False)
#     )
#   )
# )
# 2021-07-19 07:33:19 | INFO | fairseq_cli.train | task: translation (TranslationTask)
# 2021-07-19 07:33:19 | INFO | fairseq_cli.train | model: lstm (LSTMModel)
# 2021-07-19 07:33:19 | INFO | fairseq_cli.train | criterion: label_smoothed_cross_entropy (LabelSmoothedCrossEntropyCriterion)
# 2021-07-19 07:33:19 | INFO | fairseq_cli.train | num. model params: 62427136 (num. trained: 62427136)
# 2021-07-19 07:33:23 | INFO | fairseq.trainer | detected shared parameter: decoder.attention.input_proj.bias <- decoder.attention.output_proj.bias
# 2021-07-19 07:33:23 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2021-07-19 07:33:23 | INFO | fairseq.utils | rank   0: capabilities =  7.5  ; total memory = 14.756 GB ; name = Tesla T4
# 2021-07-19 07:33:23 | INFO | fairseq.utils | ***********************CUDA enviroments for all 1 workers***********************
# 2021-07-19 07:33:23 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2021-07-19 07:33:23 | INFO | fairseq_cli.train | max tokens per GPU = 4096 and max sentences per GPU = None
# 2021-07-19 07:33:23 | INFO | fairseq.trainer | no existing checkpoint found checkpoints/kftt.ja-en/checkpoint_last.pt
# 2021-07-19 07:33:23 | INFO | fairseq.trainer | loading train data for epoch 1
# 2021-07-19 07:33:23 | INFO | fairseq.data.data_utils | loaded 440288 examples from: data91/train.ja-en.ja
# 2021-07-19 07:33:23 | INFO | fairseq.data.data_utils | loaded 440288 examples from: data91/train.ja-en.en
# 2021-07-19 07:33:23 | INFO | fairseq.tasks.translation | data91 train ja-en 440288 examples
# 2021-07-19 07:33:23 | INFO | fairseq.trainer | NOTE: your device may support faster training with --fp16
# epoch 001:   0% 0/3599 [00:00<?, ?it/s]2021-07-19 07:33:23 | INFO | fairseq.trainer | begin training epoch 1
# /usr/local/lib/python3.7/dist-packages/fairseq/utils.py:342: UserWarning: amp_C fused kernels unavailable, disabling multi_tensor_l2norm; you may get better performance by installing NVIDIA's apex library
#   "amp_C fused kernels unavailable, disabling multi_tensor_l2norm; "
# epoch 001: 100% 3598/3599 [20:03<00:00,  2.90it/s, loss=8.222, nll_loss=7.056, ppl=133.06, wps=9363.5, ups=2.91, wpb=3222.8, bsz=98.2, num_updates=3500, lr=0.0004375, gnorm=0.589, train_wall=34, wall=1171]2021-07-19 07:53:27 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 001 | valid on 'valid' subset:   0% 0/13 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  /pytorch/aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)
# 2021-07-19 07:53:28 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP (Junior Fifth Rank, Lower Grade)
# 2021-07-19 07:53:28 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF TAKEKOSHI, Jugoi no ge
#
# epoch 001 | valid on 'valid' subset:   8% 1/13 [00:01<00:12,  1.03s/it]2021-07-19 07:53:29 | INFO | fairseq.tasks.translation | example hypothesis: He died in the Battle of Sekigahara in the Battle of Sekigahara.
# 2021-07-19 07:53:29 | INFO | fairseq.tasks.translation | example reference: 1600 - Burned in the Siege of Fushimi Castle
#
# epoch 001 | valid on 'valid' subset:  15% 2/13 [00:01<00:10,  1.04it/s]2021-07-19 07:53:30 | INFO | fairseq.tasks.translation | example hypothesis: The Faculty of Education and the Faculty of the University of the University of the University of the University of the University of the National Museum of the National Museum of Art.
# 2021-07-19 07:53:30 | INFO | fairseq.tasks.translation | example reference: Department of History, Japanese History Course, Asian History Course, and Buddhist History Course
#
# epoch 001 | valid on 'valid' subset:  23% 3/13 [00:02<00:09,  1.03it/s]2021-07-19 07:53:32 | INFO | fairseq.tasks.translation | example hypothesis: It is also used as a result of the station.
# 2021-07-19 07:53:32 | INFO | fairseq.tasks.translation | example reference: The rail cars all belonged to JR (Japan Railway Company) and have been remodeled for use.
#
# epoch 001 | valid on 'valid' subset:  31% 4/13 [00:04<00:10,  1.20s/it]2021-07-19 07:53:33 | INFO | fairseq.tasks.translation | example hypothesis: In 2006, he became a member of the Imperial University of the University of the University of the University of Tokyo University.
# 2021-07-19 07:53:33 | INFO | fairseq.tasks.translation | example reference: In UNKNOWNTOKENINREF, Legal Affairs Research Course of Graduate School of Law (Law School) opened and Tokyo Office was set up.
#
# epoch 001 | valid on 'valid' subset:  38% 5/13 [00:05<00:09,  1.20s/it]2021-07-19 07:53:35 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP)
# 2021-07-19 07:53:35 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF Noh Stage - UNKNOWNTOKENINREF Castle (Fukuyama City, Hiroshima Prefecture), Present-day UNKNOWNTOKENINREF Shrine (Tomonoura, Fukuyama City, Hiroshima Prefecture) (Important Cultural Property)
#
# epoch 001 | valid on 'valid' subset:  46% 6/13 [00:07<00:09,  1.43s/it]2021-07-19 07:53:37 | INFO | fairseq.tasks.translation | example hypothesis: In addition, the domain of the Satsuma Domain, the lord of the Satsuma Domain, and the lord of the domain, the lord of the Satsuma Domain, and the lord of the Satsuma Domain.
# 2021-07-19 07:53:37 | INFO | fairseq.tasks.translation | example reference: The sweep of the city turned violent, and there were 5 immediate deaths among the Aizu clan, four among the Hikone clan, and two among the Kuwana clan.
#
# epoch 001 | valid on 'valid' subset:  54% 7/13 [00:09<00:09,  1.60s/it]2021-07-19 07:53:39 | INFO | fairseq.tasks.translation | example hypothesis: According to "Kojiki" (The Records of Ancient Matters), he was said to have been killed by the Taira clan.
# 2021-07-19 07:53:39 | INFO | fairseq.tasks.translation | example reference: According to "Nan-Taiheiki", Ietoki ASHIKAGA, Takauji's grandfather, killed himself with his sword, praying that the Ashikaga clan may rule over the whole country in 3 generations.
#
# epoch 001 | valid on 'valid' subset:  62% 8/13 [00:11<00:08,  1.75s/it]2021-07-19 07:53:41 | INFO | fairseq.tasks.translation | example hypothesis: It is said that he was a member of the Imperial University of Japan, which is said to be a member of the Imperial University of Japan.
# 2021-07-19 07:53:41 | INFO | fairseq.tasks.translation | example reference: The instrument music club, once directed by Yutaka Sado, achieved the sixth, and consecutively the fourth, gold medal (as of 2006), in University Category of All Japan Band Competition.
#
# epoch 001 | valid on 'valid' subset:  69% 9/13 [00:13<00:07,  1.82s/it]2021-07-19 07:53:43 | INFO | fairseq.tasks.translation | example hypothesis: As a result, there was a result that he died in the same year, however, it is said to have been killed in the Battle of Sekigahara.
# 2021-07-19 07:53:43 | INFO | fairseq.tasks.translation | example reference: Kogoro KATSURA (later Takayoshi KIDO) should have been there too, but he arrived earlier and then went back to the base to wait a while. His life had been spared because the incident occurred before he came back.
#
# epoch 001 | valid on 'valid' subset:  77% 10/13 [00:15<00:05,  1.93s/it]2021-07-19 07:53:45 | INFO | fairseq.tasks.translation | example hypothesis: It is said that he was appointed as a member of the bakufu (Japanese feudal government headed by a shogun) of the Muromachi bakufu (Japanese feudal government headed by a shogun) in the Muromachi bakufu (Japanese feudal government headed by a shogun) in the Muromachi bakufu (Japanese feudal government headed by a shogun) in the Muromachi bakufu (Japanese feudal government headed by a shogun) in the Muromachi bakufu (Japanese feudal government headed by a shogun) in the Muromachi bakufu (Japanese feudal government headed by a shogun) in the Muromachi bakufu (Japanese feudal government headed by a shogun).
# 2021-07-19 07:53:45 | INFO | fairseq.tasks.translation | example reference: In 1481, a few years after the tumultuous Onin War (1467 - 1477), which had lasted for a decade, Sotan, the official painter for the Muromachi shogunate, died; thus it is thought that Masanobu KANO was appointed as the official painter for the shogunate, succeeding Sotan.
#
# epoch 001 | valid on 'valid' subset:  85% 11/13 [00:18<00:03,  1.96s/it]2021-07-19 07:53:47 | INFO | fairseq.tasks.translation | example hypothesis: It is also called 'UNKNOWNTOKENINHYP' in the Muromachi bakufu (the Muromachi bakufu), who was the second son of the Muromachi bakufu (Japanese feudal government headed by a shogun), who was the second son of the Muromachi bakufu (Japanese feudal government headed by a shogun), and he was called 'UNKNOWNTOKENINHYP' (UNKNOWNTOKENINHYP) of the Muromachi bakufu (Japanese feudal government headed by a shogun).
# 2021-07-19 07:53:47 | INFO | fairseq.tasks.translation | example reference: Prominent painters of the UNKNOWNTOKENINREF group include the founder Masanobu KANO, who worked for Yoshimasa ASHIKAGA, the eighth Seii taishogun (literally, "great general who subdues the barbarians") of the Muromachi shogunate; his heir, Motonobu KANO, a grandson of Motonobu; Eitoku KANO, who created screen paintings of the Azuchi and Osaka castles; a grandson of Eitoku, Tanyu KANO, who moved from Kyoto to Edo and supervised the creation of screen paintings of Edo Castle and Nijo Castle; Sanraku KANO, who stayed in Kyoto, thus representing a group called 'Kyo Kano.'
#
# epoch 001 | valid on 'valid' subset:  92% 12/13 [00:19<00:01,  1.90s/it]2021-07-19 07:53:48 | INFO | fairseq.tasks.translation | example hypothesis: It is said that the Imperial Prince (the Yodo-gawa River) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP) (UNKNOWNTOKENINHYP).
# 2021-07-19 07:53:48 | INFO | fairseq.tasks.translation | example reference: The Cloistered Emperor Shirakawa had supreme power, but it was said he UNKNOWNTOKENINREF that, he has no control over the following three things: 1. Waters of the Kamo River (tributary of the Yodo River) (due to its flow and frequent flooding); 2. UNKNOWNTOKENINREF used in sugoroku (different from current sugoroku, close to western backgammon), which was popular way of gambling at that time, with spots on the dice selecting winners / losers; and 3. UNKNOWNTOKENINREF (monk soldiers from Mt. Hie Enryaku-ji Temple), which show that SHIRAKAWA had absolute control apart from these three things.
#
# epoch 001 | valid on 'valid' subset: 100% 13/13 [00:20<00:00,  1.55s/it]
#                                                                         2021-07-19 07:53:48 | INFO | valid | epoch 001 | valid on 'valid' subset | loss 8.09 | nll_loss 6.913 | ppl 120.49 | bleu 3.03 | wps 1249.1 | wpb 1959.6 | bsz 89.7 | num_updates 3599
# 2021-07-19 07:53:48 | INFO | fairseq_cli.train | begin save checkpoint
# 2021-07-19 07:54:12 | INFO | fairseq.checkpoint_utils | saved checkpoint checkpoints/kftt.ja-en/checkpoint1.pt (epoch 1 @ 3599 updates, score 3.03) (writing took 24.621440653000263 seconds)
# 2021-07-19 07:54:12 | INFO | fairseq_cli.train | end of epoch 1 (average epoch stats below)
# 2021-07-19 07:54:12 | INFO | train | epoch 001 | loss 9.783 | nll_loss 8.845 | ppl 459.93 | wps 9592.9 | ups 2.88 | wpb 3329.2 | bsz 122.3 | num_updates 3599 | lr 0.000449875 | gnorm 0.775 | train_wall 1201 | wall 1250
# epoch 002:   0% 0/3599 [00:00<?, ?it/s]2021-07-19 07:54:12 | INFO | fairseq.trainer | begin training epoch 2
# epoch 002: 100% 3598/3599 [20:17<00:00,  3.14it/s, loss=7.175, nll_loss=5.86, ppl=58.06, wps=9705.3, ups=2.93, wpb=3307.1, bsz=121.9, num_updates=7100, lr=0.000375293, gnorm=0.567, train_wall=34, wall=2433]2021-07-19 08:14:30 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 002 | valid on 'valid' subset:   0% 0/13 [00:00<?, ?it/s]2021-07-19 08:14:31 | INFO | fairseq.tasks.translation | example hypothesis: He was Jugoinoge (Junior Fifth Rank, Lower Grade), Jugoinoge (Junior Fifth Rank, Lower Grade).
# 2021-07-19 08:14:31 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF TAKEKOSHI, Jugoi no ge
#
# epoch 002 | valid on 'valid' subset:   8% 1/13 [00:01<00:12,  1.03s/it]2021-07-19 08:14:33 | INFO | fairseq.tasks.translation | example hypothesis: In 1600, he was defeated in the Battle of Fushimi-jo Castle.
# 2021-07-19 08:14:33 | INFO | fairseq.tasks.translation | example reference: 1600 - Burned in the Siege of Fushimi Castle
#
# epoch 002 | valid on 'valid' subset:  15% 2/13 [00:02<00:12,  1.18s/it]2021-07-19 08:14:34 | INFO | fairseq.tasks.translation | example hypothesis: The Department of Art and History of Art, Culture, UNKNOWNTOKENINHYP, UNKNOWNTOKENINHYP, UNKNOWNTOKENINHYP, UNKNOWNTOKENINHYP
# 2021-07-19 08:14:34 | INFO | fairseq.tasks.translation | example reference: Department of History, Japanese History Course, Asian History Course, and Buddhist History Course
#
# epoch 002 | valid on 'valid' subset:  23% 3/13 [00:03<00:11,  1.19s/it]2021-07-19 08:14:35 | INFO | fairseq.tasks.translation | example hypothesis: It is used to be used in the JR morning.
# 2021-07-19 08:14:35 | INFO | fairseq.tasks.translation | example reference: The rail cars all belonged to JR (Japan Railway Company) and have been remodeled for use.
#
# epoch 002 | valid on 'valid' subset:  31% 4/13 [00:04<00:09,  1.10s/it]2021-07-19 08:14:36 | INFO | fairseq.tasks.translation | example hypothesis: 2005: He established the Department of Education of the University of Education, the Department of Education, the Department of Education, and the Department of Education.
# 2021-07-19 08:14:36 | INFO | fairseq.tasks.translation | example reference: In UNKNOWNTOKENINREF, Legal Affairs Research Course of Graduate School of Law (Law School) opened and Tokyo Office was set up.
#
# epoch 002 | valid on 'valid' subset:  38% 5/13 [00:06<00:10,  1.28s/it]2021-07-19 08:14:38 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP, Hiroshima City, Hiroshima Prefecture) (Important Cultural Property) (Important Cultural Property) (Important Cultural Property)
# 2021-07-19 08:14:38 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF Noh Stage - UNKNOWNTOKENINREF Castle (Fukuyama City, Hiroshima Prefecture), Present-day UNKNOWNTOKENINREF Shrine (Tomonoura, Fukuyama City, Hiroshima Prefecture) (Important Cultural Property)
#
# epoch 002 | valid on 'valid' subset:  46% 6/13 [00:08<00:10,  1.44s/it]2021-07-19 08:14:40 | INFO | fairseq.tasks.translation | example hypothesis: In addition, the domain of the Aizu Domain and the domain of the Aizu Domain had a number of four names, and the lord of the domain, and the lord of the domain.
# 2021-07-19 08:14:40 | INFO | fairseq.tasks.translation | example reference: The sweep of the city turned violent, and there were 5 immediate deaths among the Aizu clan, four among the Hikone clan, and two among the Kuwana clan.
#
# epoch 002 | valid on 'valid' subset:  54% 7/13 [00:10<00:09,  1.57s/it]2021-07-19 08:14:42 | INFO | fairseq.tasks.translation | example hypothesis: According to "Taiheiki," it is said that the Ashikaga clan, who was a grandfather of Takauji, was said to have made the power of the Ashikaga clan by his grandfather of Takauji.
# 2021-07-19 08:14:42 | INFO | fairseq.tasks.translation | example reference: According to "Nan-Taiheiki", Ietoki ASHIKAGA, Takauji's grandfather, killed himself with his sword, praying that the Ashikaga clan may rule over the whole country in 3 generations.
#
# epoch 002 | valid on 'valid' subset:  62% 8/13 [00:11<00:07,  1.59s/it]2021-07-19 08:14:43 | INFO | fairseq.tasks.translation | example hypothesis: It is also said that he was in charge of UNKNOWNTOKENINHYP, which was the first one of the University of Education, and the UNKNOWNTOKENINHYP of the University of the University of Education, which was the first day of the University of Education, was the first time of the University of Education in 2006.
# 2021-07-19 08:14:43 | INFO | fairseq.tasks.translation | example reference: The instrument music club, once directed by Yutaka Sado, achieved the sixth, and consecutively the fourth, gold medal (as of 2006), in University Category of All Japan Band Competition.
#
# epoch 002 | valid on 'valid' subset:  69% 9/13 [00:13<00:06,  1.53s/it]2021-07-19 08:14:45 | INFO | fairseq.tasks.translation | example hypothesis: Although it was not clear, he was not able to take up the castle, but after the death of the incident occurred, the incident occurred at the time of the time, but the incident occurred at the time of the time.
# 2021-07-19 08:14:45 | INFO | fairseq.tasks.translation | example reference: Kogoro KATSURA (later Takayoshi KIDO) should have been there too, but he arrived earlier and then went back to the base to wait a while. His life had been spared because the incident occurred before he came back.
#
# epoch 002 | valid on 'valid' subset:  77% 10/13 [00:14<00:04,  1.55s/it]2021-07-19 08:14:47 | INFO | fairseq.tasks.translation | example hypothesis: It is said that he was a painter of the Muromachi bakufu (Japanese feudal government headed by a shogun) during the period of the Muromachi bakufu (Japanese feudal government headed by a shogun) of the Muromachi bakufu (Japanese feudal government headed by a shogun) of the Muromachi bakufu (Japanese feudal government headed by a shogun) of the Muromachi bakufu (Japanese feudal government headed by a shogun) of the Muromachi bakufu (Japanese feudal government headed by a shogun) of the Muromachi bakufu (Japanese feudal government headed by a shogun) of the Muromachi bakufu (Japanese feudal government headed by a shogun).
# 2021-07-19 08:14:47 | INFO | fairseq.tasks.translation | example reference: In 1481, a few years after the tumultuous Onin War (1467 - 1477), which had lasted for a decade, Sotan, the official painter for the Muromachi shogunate, died; thus it is thought that Masanobu KANO was appointed as the official painter for the shogunate, succeeding Sotan.
#
# epoch 002 | valid on 'valid' subset:  85% 11/13 [00:16<00:03,  1.63s/it]2021-07-19 08:14:48 | INFO | fairseq.tasks.translation | example hypothesis: As a representative of the Kano school, he was a disciple of the Kano school, who served as the sixth shogun of the Muromachi bakufu (Japanese feudal government headed by a shogun), and the eldest son of Yoshiteru ASHIKAGA, who was the founder of the Muromachi bakufu (Japanese feudal government headed by a shogun), he moved to Kyoto and moved to Kyoto, and he moved to Kyoto, and he moved to Kyoto, and he moved to Kyoto, and he moved to Kyoto and moved to Kyoto.
# 2021-07-19 08:14:48 | INFO | fairseq.tasks.translation | example reference: Prominent painters of the UNKNOWNTOKENINREF group include the founder Masanobu KANO, who worked for Yoshimasa ASHIKAGA, the eighth Seii taishogun (literally, "great general who subdues the barbarians") of the Muromachi shogunate; his heir, Motonobu KANO, a grandson of Motonobu; Eitoku KANO, who created screen paintings of the Azuchi and Osaka castles; a grandson of Eitoku, Tanyu KANO, who moved from Kyoto to Edo and supervised the creation of screen paintings of Edo Castle and Nijo Castle; Sanraku KANO, who stayed in Kyoto, thus representing a group called 'Kyo Kano.'
#
# epoch 002 | valid on 'valid' subset:  92% 12/13 [00:18<00:01,  1.69s/it]2021-07-19 08:14:49 | INFO | fairseq.tasks.translation | example hypothesis: When the Cloistered Emperor Shirakawa, the Cloistered Emperor Shirakawa (the Yodo-gawa River system), which is said to have been used by the Cloistered Emperor Shirakawa (the Yodo-gawa River system), which is said to have been used as a kind of UNKNOWNTOKENINHYP (the Yodo-gawa River), it is said that it was not used as a kind of UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP), and it is said that it was not used as a kind of UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP) of Enryaku-ji Temple.
# 2021-07-19 08:14:49 | INFO | fairseq.tasks.translation | example reference: The Cloistered Emperor Shirakawa had supreme power, but it was said he UNKNOWNTOKENINREF that, he has no control over the following three things: 1. Waters of the Kamo River (tributary of the Yodo River) (due to its flow and frequent flooding); 2. UNKNOWNTOKENINREF used in sugoroku (different from current sugoroku, close to western backgammon), which was popular way of gambling at that time, with spots on the dice selecting winners / losers; and 3. UNKNOWNTOKENINREF (monk soldiers from Mt. Hie Enryaku-ji Temple), which show that SHIRAKAWA had absolute control apart from these three things.
#
# epoch 002 | valid on 'valid' subset: 100% 13/13 [00:19<00:00,  1.50s/it]
#                                                                         2021-07-19 08:14:49 | INFO | valid | epoch 002 | valid on 'valid' subset | loss 7.003 | nll_loss 5.668 | ppl 50.83 | bleu 7.4 | wps 1325.6 | wpb 1959.6 | bsz 89.7 | num_updates 7198 | best_bleu 7.4
# 2021-07-19 08:14:49 | INFO | fairseq_cli.train | begin save checkpoint
# 2021-07-19 08:15:14 | INFO | fairseq.checkpoint_utils | saved checkpoint checkpoints/kftt.ja-en/checkpoint2.pt (epoch 2 @ 7198 updates, score 7.4) (writing took 24.860913719000564 seconds)
# 2021-07-19 08:15:14 | INFO | fairseq_cli.train | end of epoch 2 (average epoch stats below)
# 2021-07-19 08:15:14 | INFO | train | epoch 002 | loss 7.553 | nll_loss 6.291 | ppl 78.32 | wps 9494 | ups 2.85 | wpb 3329.2 | bsz 122.3 | num_updates 7198 | lr 0.00037273 | gnorm 0.569 | train_wall 1214 | wall 2512
# epoch 003:   0% 0/3599 [00:00<?, ?it/s]2021-07-19 08:15:14 | INFO | fairseq.trainer | begin training epoch 3
# epoch 003: 100% 3598/3599 [20:16<00:00,  3.07it/s, loss=6.84, nll_loss=5.481, ppl=44.65, wps=9959.2, ups=2.94, wpb=3385.9, bsz=118.7, num_updates=10700, lr=0.000305709, gnorm=0.545, train_wall=34, wall=3696]2021-07-19 08:35:32 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 003 | valid on 'valid' subset:   0% 0/13 [00:00<?, ?it/s]2021-07-19 08:35:33 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP: Jugoinoge (Junior Fifth Rank, Lower Grade)
# 2021-07-19 08:35:33 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF TAKEKOSHI, Jugoi no ge
#
# epoch 003 | valid on 'valid' subset:   8% 1/13 [00:00<00:09,  1.21it/s]2021-07-19 08:35:33 | INFO | fairseq.tasks.translation | example hypothesis: In 1600, he was burnt down in the Battle of Fushimi-jo Castle.
# 2021-07-19 08:35:33 | INFO | fairseq.tasks.translation | example reference: 1600 - Burned in the Siege of Fushimi Castle
#
# epoch 003 | valid on 'valid' subset:  15% 2/13 [00:01<00:08,  1.24it/s]2021-07-19 08:35:34 | INFO | fairseq.tasks.translation | example hypothesis: Graduate School of History of Ancient and Modern History of Ancient Studies and History of Ancient Studies
# 2021-07-19 08:35:34 | INFO | fairseq.tasks.translation | example reference: Department of History, Japanese History Course, Asian History Course, and Buddhist History Course
#
# epoch 003 | valid on 'valid' subset:  23% 3/13 [00:02<00:08,  1.20it/s]2021-07-19 08:35:35 | INFO | fairseq.tasks.translation | example hypothesis: It has been used for the number of cars which had been operated by the JR West.
# 2021-07-19 08:35:35 | INFO | fairseq.tasks.translation | example reference: The rail cars all belonged to JR (Japan Railway Company) and have been remodeled for use.
#
# epoch 003 | valid on 'valid' subset:  31% 4/13 [00:03<00:07,  1.19it/s]2021-07-19 08:35:36 | INFO | fairseq.tasks.translation | example hypothesis: 2005: He established the Graduate School of Education, the Graduate School of Education, and was established in Tokyo.
# 2021-07-19 08:35:36 | INFO | fairseq.tasks.translation | example reference: In UNKNOWNTOKENINREF, Legal Affairs Research Course of Graduate School of Law (Law School) opened and Tokyo Office was set up.
#
# epoch 003 | valid on 'valid' subset:  38% 5/13 [00:04<00:07,  1.06it/s]2021-07-19 08:35:38 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP): UNKNOWNTOKENINHYP Castle (Hiroshima City, Hiroshima Prefecture), today's UNKNOWNTOKENINHYP Shrine (UNKNOWNTOKENINHYP, Hiroshima City, Hiroshima Prefecture) (Important Cultural Property)
# 2021-07-19 08:35:38 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF Noh Stage - UNKNOWNTOKENINREF Castle (Fukuyama City, Hiroshima Prefecture), Present-day UNKNOWNTOKENINREF Shrine (Tomonoura, Fukuyama City, Hiroshima Prefecture) (Important Cultural Property)
#
# epoch 003 | valid on 'valid' subset:  46% 6/13 [00:06<00:07,  1.12s/it]2021-07-19 08:35:39 | INFO | fairseq.tasks.translation | example hypothesis: In addition to the battle, the Aizu Domain became a fierce battle, and the domain of the Hikone Domain had two sons, and the lord of the Hikone Domain had two sons.
# 2021-07-19 08:35:39 | INFO | fairseq.tasks.translation | example reference: The sweep of the city turned violent, and there were 5 immediate deaths among the Aizu clan, four among the Hikone clan, and two among the Kuwana clan.
#
# epoch 003 | valid on 'valid' subset:  54% 7/13 [00:07<00:07,  1.21s/it]2021-07-19 08:35:41 | INFO | fairseq.tasks.translation | example hypothesis: According to "Taiheiki" (The Record of the Great Peace), it is said that the Ashikaga clan, the grandfather of Takauji, was said to have committed suicide by his grandfather, the Ashikaga clan.
# 2021-07-19 08:35:41 | INFO | fairseq.tasks.translation | example reference: According to "Nan-Taiheiki", Ietoki ASHIKAGA, Takauji's grandfather, killed himself with his sword, praying that the Ashikaga clan may rule over the whole country in 3 generations.
#
# epoch 003 | valid on 'valid' subset:  62% 8/13 [00:09<00:07,  1.45s/it]2021-07-19 08:35:43 | INFO | fairseq.tasks.translation | example hypothesis: In the past, in the past, he was said to have been in charge of UNKNOWNTOKENINHYP (the Department of Education), which is said to have been in charge of UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP), and in the middle of the four days of the UNKNOWNTOKENINHYP (the first day in 2006).
# 2021-07-19 08:35:43 | INFO | fairseq.tasks.translation | example reference: The instrument music club, once directed by Yutaka Sado, achieved the sixth, and consecutively the fourth, gold medal (as of 2006), in University Category of All Japan Band Competition.
#
# epoch 003 | valid on 'valid' subset:  69% 9/13 [00:10<00:05,  1.45s/it]2021-07-19 08:35:44 | INFO | fairseq.tasks.translation | example hypothesis: In the case of Katsura KATSURA (later, Takayoshi KIDO), however, the incident occurred in the place where he was alive, but he went to the place of the place where he went to the place, and the incident occurred in the end of the time.
# 2021-07-19 08:35:44 | INFO | fairseq.tasks.translation | example reference: Kogoro KATSURA (later Takayoshi KIDO) should have been there too, but he arrived earlier and then went back to the base to wait a while. His life had been spared because the incident occurred before he came back.
#
# epoch 003 | valid on 'valid' subset:  77% 10/13 [00:12<00:04,  1.55s/it]2021-07-19 08:35:46 | INFO | fairseq.tasks.translation | example hypothesis: It is said that the Onin War (Onin War), which was a painter of the Muromachi bakufu (Japanese feudal government headed by a shogun), died at the end of the Onin War (Onin War), and he was appointed as a painter in the Muromachi bakufu (Japanese feudal government headed by a shogun) and was appointed as a painter of the bakufu (Japanese feudal government headed by a shogun) and was appointed as a painter of the bakufu (Japanese feudal government headed by a shogun).
# 2021-07-19 08:35:46 | INFO | fairseq.tasks.translation | example reference: In 1481, a few years after the tumultuous Onin War (1467 - 1477), which had lasted for a decade, Sotan, the official painter for the Muromachi shogunate, died; thus it is thought that Masanobu KANO was appointed as the official painter for the shogunate, succeeding Sotan.
#
# epoch 003 | valid on 'valid' subset:  85% 11/13 [00:14<00:03,  1.58s/it]2021-07-19 08:35:48 | INFO | fairseq.tasks.translation | example hypothesis: As a representative painter of the Kano school, he moved from Kyoto to Edo, and in Kyoto, he moved to Kyoto, and he moved to Kyoto in Kyoto, and he was called 'UNKNOWNTOKENINHYP' in Kyoto.
# 2021-07-19 08:35:48 | INFO | fairseq.tasks.translation | example reference: Prominent painters of the UNKNOWNTOKENINREF group include the founder Masanobu KANO, who worked for Yoshimasa ASHIKAGA, the eighth Seii taishogun (literally, "great general who subdues the barbarians") of the Muromachi shogunate; his heir, Motonobu KANO, a grandson of Motonobu; Eitoku KANO, who created screen paintings of the Azuchi and Osaka castles; a grandson of Eitoku, Tanyu KANO, who moved from Kyoto to Edo and supervised the creation of screen paintings of Edo Castle and Nijo Castle; Sanraku KANO, who stayed in Kyoto, thus representing a group called 'Kyo Kano.'
#
# epoch 003 | valid on 'valid' subset:  92% 12/13 [00:15<00:01,  1.58s/it]2021-07-19 08:35:48 | INFO | fairseq.tasks.translation | example hypothesis: It is said that the Cloistered Emperor Shirakawa had a strong power that the Cloistered Emperor Shirakawa was not used as a symbol of the Kamo-gawa River (the Kamo-gawa River) (the Yodo-gawa River system), which is said to have been used as a symbol of the UNKNOWNTOKENINHYP (the Kamo-gawa River), which is said to have been used as a means of UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP), which is said to have been used as a means of UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP) of Enryaku-ji Temple of Mt. Hiei.
# 2021-07-19 08:35:48 | INFO | fairseq.tasks.translation | example reference: The Cloistered Emperor Shirakawa had supreme power, but it was said he UNKNOWNTOKENINREF that, he has no control over the following three things: 1. Waters of the Kamo River (tributary of the Yodo River) (due to its flow and frequent flooding); 2. UNKNOWNTOKENINREF used in sugoroku (different from current sugoroku, close to western backgammon), which was popular way of gambling at that time, with spots on the dice selecting winners / losers; and 3. UNKNOWNTOKENINREF (monk soldiers from Mt. Hie Enryaku-ji Temple), which show that SHIRAKAWA had absolute control apart from these three things.
#
# epoch 003 | valid on 'valid' subset: 100% 13/13 [00:16<00:00,  1.33s/it]
#                                                                         2021-07-19 08:35:48 | INFO | valid | epoch 003 | valid on 'valid' subset | loss 6.642 | nll_loss 5.257 | ppl 38.24 | bleu 9.61 | wps 1535.3 | wpb 1959.6 | bsz 89.7 | num_updates 10797 | best_bleu 9.61
# 2021-07-19 08:35:48 | INFO | fairseq_cli.train | begin save checkpoint
# 2021-07-19 08:36:13 | INFO | fairseq.checkpoint_utils | saved checkpoint checkpoints/kftt.ja-en/checkpoint3.pt (epoch 3 @ 10797 updates, score 9.61) (writing took 24.206135636 seconds)
# 2021-07-19 08:36:13 | INFO | fairseq_cli.train | end of epoch 3 (average epoch stats below)
# 2021-07-19 08:36:13 | INFO | train | epoch 003 | loss 6.945 | nll_loss 5.599 | ppl 48.48 | wps 9522.2 | ups 2.86 | wpb 3329.2 | bsz 122.3 | num_updates 10797 | lr 0.000304333 | gnorm 0.564 | train_wall 1214 | wall 3770
# epoch 004:   0% 0/3599 [00:00<?, ?it/s]2021-07-19 08:36:13 | INFO | fairseq.trainer | begin training epoch 4
# epoch 004: 100% 3598/3599 [20:16<00:00,  2.91it/s, loss=6.565, nll_loss=5.168, ppl=35.95, wps=9891.3, ups=3.02, wpb=3276, bsz=127.4, num_updates=14300, lr=0.000264443, gnorm=0.562, train_wall=33, wall=4955]2021-07-19 08:56:30 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 004 | valid on 'valid' subset:   0% 0/13 [00:00<?, ?it/s]2021-07-19 08:56:31 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP: Jugoinoge (Junior Fifth Rank, Lower Grade)
# 2021-07-19 08:56:31 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF TAKEKOSHI, Jugoi no ge
#
# epoch 004 | valid on 'valid' subset:   8% 1/13 [00:00<00:10,  1.13it/s]2021-07-19 08:56:32 | INFO | fairseq.tasks.translation | example hypothesis: In 1600, he was burnt down in the Battle of Fushimi-jo Castle.
# 2021-07-19 08:56:32 | INFO | fairseq.tasks.translation | example reference: 1600 - Burned in the Siege of Fushimi Castle
#
# epoch 004 | valid on 'valid' subset:  15% 2/13 [00:01<00:09,  1.18it/s]2021-07-19 08:56:33 | INFO | fairseq.tasks.translation | example hypothesis: Department of History of Ancient and Modern Japanese History
# 2021-07-19 08:56:33 | INFO | fairseq.tasks.translation | example reference: Department of History, Japanese History Course, Asian History Course, and Buddhist History Course
#
# epoch 004 | valid on 'valid' subset:  23% 3/13 [00:02<00:08,  1.13it/s]2021-07-19 08:56:34 | INFO | fairseq.tasks.translation | example hypothesis: It is used for the cars that had been operated by the JR.
# 2021-07-19 08:56:34 | INFO | fairseq.tasks.translation | example reference: The rail cars all belonged to JR (Japan Railway Company) and have been remodeled for use.
#
# epoch 004 | valid on 'valid' subset:  31% 4/13 [00:03<00:07,  1.13it/s]2021-07-19 08:56:35 | INFO | fairseq.tasks.translation | example hypothesis: 2005: He established the Graduate School of the University of Education, the Department of Education, and established the establishment of Tokyo.
# 2021-07-19 08:56:35 | INFO | fairseq.tasks.translation | example reference: In UNKNOWNTOKENINREF, Legal Affairs Research Course of Graduate School of Law (Law School) opened and Tokyo Office was set up.
#
# epoch 004 | valid on 'valid' subset:  38% 5/13 [00:04<00:07,  1.04it/s]2021-07-19 08:56:36 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP): UNKNOWNTOKENINHYP Castle (Fukuyama City, Hiroshima Prefecture), UNKNOWNTOKENINHYP Shrine (Fukuyama City, Hiroshima Prefecture) (Important Cultural Property)
# 2021-07-19 08:56:36 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF Noh Stage - UNKNOWNTOKENINREF Castle (Fukuyama City, Hiroshima Prefecture), Present-day UNKNOWNTOKENINREF Shrine (Tomonoura, Fukuyama City, Hiroshima Prefecture) (Important Cultural Property)
#
# epoch 004 | valid on 'valid' subset:  46% 6/13 [00:05<00:07,  1.03s/it]2021-07-19 08:56:37 | INFO | fairseq.tasks.translation | example hypothesis: In the city, the Aizu Domain became a fierce battle, and the Aizu Domain had four members of the domain, and the domain of Hikone, and the Hikone Domain had two sons.
# 2021-07-19 08:56:37 | INFO | fairseq.tasks.translation | example reference: The sweep of the city turned violent, and there were 5 immediate deaths among the Aizu clan, four among the Hikone clan, and two among the Kuwana clan.
#
# epoch 004 | valid on 'valid' subset:  54% 7/13 [00:07<00:06,  1.12s/it]2021-07-19 08:56:39 | INFO | fairseq.tasks.translation | example hypothesis: According to "Taiheiki" (The Record of the Great Peace), it is said that the Ashikaga clan, the grandfather of Takauji, was killed by his grandfather, the Ashikaga clan, and committed suicide by the Ashikaga clan.
# 2021-07-19 08:56:39 | INFO | fairseq.tasks.translation | example reference: According to "Nan-Taiheiki", Ietoki ASHIKAGA, Takauji's grandfather, killed himself with his sword, praying that the Ashikaga clan may rule over the whole country in 3 generations.
#
# epoch 004 | valid on 'valid' subset:  62% 8/13 [00:09<00:06,  1.37s/it]2021-07-19 08:56:41 | INFO | fairseq.tasks.translation | example hypothesis: In the past, the UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP), which was said to have been under the command of Sado in Sado, was in the center of the University of Japan, and the UNKNOWNTOKENINHYP (the first half of the year of 2006) in the Faculty of Medicine, the first half of the four six years.
# 2021-07-19 08:56:41 | INFO | fairseq.tasks.translation | example reference: The instrument music club, once directed by Yutaka Sado, achieved the sixth, and consecutively the fourth, gold medal (as of 2006), in University Category of All Japan Band Competition.
#
# epoch 004 | valid on 'valid' subset:  69% 9/13 [00:10<00:05,  1.39s/it]2021-07-19 08:56:43 | INFO | fairseq.tasks.translation | example hypothesis: Although it was originally said that he had already been said to have been in this place, the incident occurred at the time, but the incident occurred at the end of the time, and the incident occurred at the time of the time, and the incident occurred.
# 2021-07-19 08:56:43 | INFO | fairseq.tasks.translation | example reference: Kogoro KATSURA (later Takayoshi KIDO) should have been there too, but he arrived earlier and then went back to the base to wait a while. His life had been spared because the incident occurred before he came back.
#
# epoch 004 | valid on 'valid' subset:  77% 10/13 [00:12<00:04,  1.57s/it]2021-07-19 08:56:44 | INFO | fairseq.tasks.translation | example hypothesis: It is said that the Onin War (in the Onin War), which was a painter of the Muromachi bakufu (Japanese feudal government headed by a shogun), died in 1549, and was appointed as a painter of the bakufu (Japanese feudal government headed by a shogun), and was appointed as a painter of the bakufu (Japanese feudal government headed by a shogun) and was appointed as a painter of the bakufu (Japanese feudal government headed by a shogun).
# 2021-07-19 08:56:44 | INFO | fairseq.tasks.translation | example reference: In 1481, a few years after the tumultuous Onin War (1467 - 1477), which had lasted for a decade, Sotan, the official painter for the Muromachi shogunate, died; thus it is thought that Masanobu KANO was appointed as the official painter for the shogunate, succeeding Sotan.
#
# epoch 004 | valid on 'valid' subset:  85% 11/13 [00:14<00:03,  1.60s/it]2021-07-19 08:56:46 | INFO | fairseq.tasks.translation | example hypothesis: As a representative painter of the Kano school, the founder of the Kano school, including KANO KANO, who served as the eighth shogun of the Kano school, had served as the eighth shogun of the Muromachi bakufu (Japanese feudal government headed by a shogun), and he moved to Kyoto in Kyoto, and he moved to Kyoto in Kyoto, and he was called 'Kyoto KANO' in Kyoto, which was called 'Kyoto KANO,' which was called 'Kyoto KANO,' which was called 'Kyoto KANO,' which was called 'Kyoto KANO' in Kyoto.
# 2021-07-19 08:56:46 | INFO | fairseq.tasks.translation | example reference: Prominent painters of the UNKNOWNTOKENINREF group include the founder Masanobu KANO, who worked for Yoshimasa ASHIKAGA, the eighth Seii taishogun (literally, "great general who subdues the barbarians") of the Muromachi shogunate; his heir, Motonobu KANO, a grandson of Motonobu; Eitoku KANO, who created screen paintings of the Azuchi and Osaka castles; a grandson of Eitoku, Tanyu KANO, who moved from Kyoto to Edo and supervised the creation of screen paintings of Edo Castle and Nijo Castle; Sanraku KANO, who stayed in Kyoto, thus representing a group called 'Kyo Kano.'
#
# epoch 004 | valid on 'valid' subset:  92% 12/13 [00:15<00:01,  1.61s/it]2021-07-19 08:56:47 | INFO | fairseq.tasks.translation | example hypothesis: Although the Cloistered Emperor Shirakawa, the Cloistered Emperor Shirakawa, was used as a means of the Kamo-gawa River (Yodo-gawa River system), the water of the Kamo-gawa River (the Kamo-gawa River), the water of the Kamo-gawa River (the Kamo-gawa River), and it is said that there is no historical view that he was not used as a means of 'UNKNOWNTOKENINHYP' (UNKNOWNTOKENINHYP), and it is said that he did not have a strong power in the world, but it is said that he did not have a strong power in the world, and it is said that he did not have a strong power of UNKNOWNTOKENINHYP.
# 2021-07-19 08:56:47 | INFO | fairseq.tasks.translation | example reference: The Cloistered Emperor Shirakawa had supreme power, but it was said he UNKNOWNTOKENINREF that, he has no control over the following three things: 1. Waters of the Kamo River (tributary of the Yodo River) (due to its flow and frequent flooding); 2. UNKNOWNTOKENINREF used in sugoroku (different from current sugoroku, close to western backgammon), which was popular way of gambling at that time, with spots on the dice selecting winners / losers; and 3. UNKNOWNTOKENINREF (monk soldiers from Mt. Hie Enryaku-ji Temple), which show that SHIRAKAWA had absolute control apart from these three things.
#
# epoch 004 | valid on 'valid' subset: 100% 13/13 [00:16<00:00,  1.36s/it]
#                                                                         2021-07-19 08:56:47 | INFO | valid | epoch 004 | valid on 'valid' subset | loss 6.441 | nll_loss 5.017 | ppl 32.38 | bleu 10.27 | wps 1544.9 | wpb 1959.6 | bsz 89.7 | num_updates 14396 | best_bleu 10.27
# 2021-07-19 08:56:47 | INFO | fairseq_cli.train | begin save checkpoint
# 2021-07-19 08:57:12 | INFO | fairseq.checkpoint_utils | saved checkpoint checkpoints/kftt.ja-en/checkpoint4.pt (epoch 4 @ 14396 updates, score 10.27) (writing took 24.9487514249995 seconds)
# 2021-07-19 08:57:12 | INFO | fairseq_cli.train | end of epoch 4 (average epoch stats below)
# 2021-07-19 08:57:12 | INFO | train | epoch 004 | loss 6.665 | nll_loss 5.281 | ppl 38.89 | wps 9516.7 | ups 2.86 | wpb 3329.2 | bsz 122.3 | num_updates 14396 | lr 0.00026356 | gnorm 0.568 | train_wall 1214 | wall 5029
# epoch 005:   0% 0/3599 [00:00<?, ?it/s]2021-07-19 08:57:12 | INFO | fairseq.trainer | begin training epoch 5
# epoch 005: 100% 3598/3599 [20:17<00:00,  3.29it/s, loss=6.481, nll_loss=5.072, ppl=33.63, wps=9920.3, ups=2.89, wpb=3428.6, bsz=102.5, num_updates=17900, lr=0.00023636, gnorm=0.551, train_wall=34, wall=6215]2021-07-19 09:17:30 | INFO | fairseq_cli.train | begin validation on "valid" subset
#
# epoch 005 | valid on 'valid' subset:   0% 0/13 [00:00<?, ?it/s]2021-07-19 09:17:31 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP: Jugoinoge (Junior Fifth Rank, Lower Grade)
# 2021-07-19 09:17:31 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF TAKEKOSHI, Jugoi no ge
#
# epoch 005 | valid on 'valid' subset:   8% 1/13 [00:00<00:10,  1.15it/s]2021-07-19 09:17:31 | INFO | fairseq.tasks.translation | example hypothesis: In 1600, he was burnt down in the Battle of Fushimi-jo Castle.
# 2021-07-19 09:17:31 | INFO | fairseq.tasks.translation | example reference: 1600 - Burned in the Siege of Fushimi Castle
#
# epoch 005 | valid on 'valid' subset:  15% 2/13 [00:01<00:09,  1.20it/s]2021-07-19 09:17:32 | INFO | fairseq.tasks.translation | example hypothesis: Graduate School of History of History of History and History of History of History of History
# 2021-07-19 09:17:32 | INFO | fairseq.tasks.translation | example reference: Department of History, Japanese History Course, Asian History Course, and Buddhist History Course
#
# epoch 005 | valid on 'valid' subset:  23% 3/13 [00:02<00:08,  1.18it/s]2021-07-19 09:17:33 | INFO | fairseq.tasks.translation | example hypothesis: All of them are operated by the JR.
# 2021-07-19 09:17:33 | INFO | fairseq.tasks.translation | example reference: The rail cars all belonged to JR (Japan Railway Company) and have been remodeled for use.
#
# epoch 005 | valid on 'valid' subset:  31% 4/13 [00:03<00:07,  1.18it/s]2021-07-19 09:17:34 | INFO | fairseq.tasks.translation | example hypothesis: 2005: He established the Graduate School of Education, the Department of Education, and established the establishment of Tokyo University.
# 2021-07-19 09:17:34 | INFO | fairseq.tasks.translation | example reference: In UNKNOWNTOKENINREF, Legal Affairs Research Course of Graduate School of Law (Law School) opened and Tokyo Office was set up.
#
# epoch 005 | valid on 'valid' subset:  38% 5/13 [00:04<00:07,  1.10it/s]2021-07-19 09:17:35 | INFO | fairseq.tasks.translation | example hypothesis: UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP): UNKNOWNTOKENINHYP Castle (Fukuyama City, Hiroshima Prefecture), UNKNOWNTOKENINHYP Shrine (UNKNOWNTOKENINHYP, Hiroshima City) (Important Cultural Property)
# 2021-07-19 09:17:35 | INFO | fairseq.tasks.translation | example reference: UNKNOWNTOKENINREF Noh Stage - UNKNOWNTOKENINREF Castle (Fukuyama City, Hiroshima Prefecture), Present-day UNKNOWNTOKENINREF Shrine (Tomonoura, Fukuyama City, Hiroshima Prefecture) (Important Cultural Property)
#
# epoch 005 | valid on 'valid' subset:  46% 6/13 [00:05<00:06,  1.02it/s]2021-07-19 09:17:36 | INFO | fairseq.tasks.translation | example hypothesis: In addition, the Aizu Domain became a fierce battle, and the Aizu Domain had four members of the Aizu Domain, and the domain of Kuwana Domain had two sons.
# 2021-07-19 09:17:36 | INFO | fairseq.tasks.translation | example reference: The sweep of the city turned violent, and there were 5 immediate deaths among the Aizu clan, four among the Hikone clan, and two among the Kuwana clan.
#
# epoch 005 | valid on 'valid' subset:  54% 7/13 [00:06<00:06,  1.05s/it]2021-07-19 09:17:38 | INFO | fairseq.tasks.translation | example hypothesis: According to "Taiheiki" (The Record of the Great Peace), it is said that the Ashikaga clan took over the whole country after the death of Takauji's grandfather, the Ashikaga clan.
# 2021-07-19 09:17:38 | INFO | fairseq.tasks.translation | example reference: According to "Nan-Taiheiki", Ietoki ASHIKAGA, Takauji's grandfather, killed himself with his sword, praying that the Ashikaga clan may rule over the whole country in 3 generations.
#
# epoch 005 | valid on 'valid' subset:  62% 8/13 [00:08<00:05,  1.16s/it]2021-07-19 09:17:39 | INFO | fairseq.tasks.translation | example hypothesis: In the past, UNKNOWNTOKENINHYP (UNKNOWNTOKENINHYP), which was said to have been under the command of Sado in Sado, had four times four times, and in the end of 2006, the UNKNOWNTOKENINHYP (the second highest of the Japanese art of Japan) was completed.
# 2021-07-19 09:17:39 | INFO | fairseq.tasks.translation | example reference: The instrument music club, once directed by Yutaka Sado, achieved the sixth, and consecutively the fourth, gold medal (as of 2006), in University Category of All Japan Band Competition.
#
# epoch 005 | valid on 'valid' subset:  69% 9/13 [00:09<00:04,  1.22s/it]2021-07-19 09:17:41 | INFO | fairseq.tasks.translation | example hypothesis: If it was originally a place, the incident occurred in the place, but when he arrived at the place, he went back to the place where he was too early, and the incident occurred at the end of the time.
# 2021-07-19 09:17:41 | INFO | fairseq.tasks.translation | example reference: Kogoro KATSURA (later Takayoshi KIDO) should have been there too, but he arrived earlier and then went back to the base to wait a while. His life had been spared because the incident occurred before he came back.
#
# epoch 005 | valid on 'valid' subset:  77% 10/13 [00:10<00:03,  1.29s/it]2021-07-19 09:17:42 | INFO | fairseq.tasks.translation | example hypothesis: In the Onin War (1467), a few years after the Onin War (1467), who was a painter of the Muromachi bakufu (Japanese feudal government headed by a shogun), passed away, he was appointed as a painter of the bakufu (Japanese feudal government headed by a shogun) and was appointed as a painter of the bakufu (Japanese feudal government headed by a shogun).
# 2021-07-19 09:17:42 | INFO | fairseq.tasks.translation | example reference: In 1481, a few years after the tumultuous Onin War (1467 - 1477), which had lasted for a decade, Sotan, the official painter for the Muromachi shogunate, died; thus it is thought that Masanobu KANO was appointed as the official painter for the shogunate, succeeding Sotan.
#
# epoch 005 | valid on 'valid' subset:  85% 11/13 [00:12<00:02,  1.39s/it]2021-07-19 09:17:44 | INFO | fairseq.tasks.translation | example hypothesis: As a representative painter of the Kano school, he moved from Kyoto to Edo by the eighth shogun Yoshimasa ASHIKAGA, and the son of Eitoku KANO, the eldest son of Eitoku KANO, and the grandson of Eitoku KANO, who was a disciple of Eitoku KANO, who was a disciple of Eitoku KANO, and others in Kyoto, and in Kyoto, he was called 'Kyoto Kano' (The Kano School of Kyoto), and the group of Kano KANO, which was called 'Kyoto Kano' (The Kano School of Kyoto), and so on, including KANO KANO, the grandson of Eitoku KANO, and others.
# 2021-07-19 09:17:44 | INFO | fairseq.tasks.translation | example reference: Prominent painters of the UNKNOWNTOKENINREF group include the founder Masanobu KANO, who worked for Yoshimasa ASHIKAGA, the eighth Seii taishogun (literally, "great general who subdues the barbarians") of the Muromachi shogunate; his heir, Motonobu KANO, a grandson of Motonobu; Eitoku KANO, who created screen paintings of the Azuchi and Osaka castles; a grandson of Eitoku, Tanyu KANO, who moved from Kyoto to Edo and supervised the creation of screen paintings of Edo Castle and Nijo Castle; Sanraku KANO, who stayed in Kyoto, thus representing a group called 'Kyo Kano.'
#
# epoch 005 | valid on 'valid' subset:  92% 12/13 [00:14<00:01,  1.45s/it]2021-07-19 09:17:45 | INFO | fairseq.tasks.translation | example hypothesis: The historical event that the Cloistered Emperor Shirakawa had a great power in the Kamo-gawa River (the Kamo-gawa River), the water of the Kamo-gawa River (the Kamo-gawa River), the water of the Kamo-gawa River (the Kamo-gawa River), and it is said that there was no political power in which he could not have a strong power, and it is said that he did not have a strong power as a means, and it is said that he did not have a strong power as a means, and it is said that he did not have a strong power as a means.
# 2021-07-19 09:17:45 | INFO | fairseq.tasks.translation | example reference: The Cloistered Emperor Shirakawa had supreme power, but it was said he UNKNOWNTOKENINREF that, he has no control over the following three things: 1. Waters of the Kamo River (tributary of the Yodo River) (due to its flow and frequent flooding); 2. UNKNOWNTOKENINREF used in sugoroku (different from current sugoroku, close to western backgammon), which was popular way of gambling at that time, with spots on the dice selecting winners / losers; and 3. UNKNOWNTOKENINREF (monk soldiers from Mt. Hie Enryaku-ji Temple), which show that SHIRAKAWA had absolute control apart from these three things.
#
# epoch 005 | valid on 'valid' subset: 100% 13/13 [00:14<00:00,  1.23s/it]
#                                                                         2021-07-19 09:17:45 | INFO | valid | epoch 005 | valid on 'valid' subset | loss 6.333 | nll_loss 4.912 | ppl 30.11 | bleu 11.98 | wps 1731.3 | wpb 1959.6 | bsz 89.7 | num_updates 17995 | best_bleu 11.98
# 2021-07-19 09:17:45 | INFO | fairseq_cli.train | begin save checkpoint
# 2021-07-19 09:18:14 | INFO | fairseq.checkpoint_utils | saved checkpoint checkpoints/kftt.ja-en/checkpoint5.pt (epoch 5 @ 17995 updates, score 11.98) (writing took 29.62300774799951 seconds)
# 2021-07-19 09:18:14 | INFO | fairseq_cli.train | end of epoch 5 (average epoch stats below)
# 2021-07-19 09:18:14 | INFO | train | epoch 005 | loss 6.494 | nll_loss 5.087 | ppl 33.99 | wps 9489.4 | ups 2.85 | wpb 3329.2 | bsz 122.3 | num_updates 17995 | lr 0.000235735 | gnorm 0.578 | train_wall 1215 | wall 6292
# 2021-07-19 09:18:14 | INFO | fairseq_cli.train | done training in 6291.1 seconds

# %% [markdown]
# *   ./data-bin/: 第一引数はモデルの保存先を指定します。これがデフォルトのようです
#
# *   --lr: learning rateはデータ、バッチサイズなどで大きく適切な値が変わります。1e-5がよく使われているらしいです．
#
# *   --warmup-updates: このパラメータの回数分のminibatchを処理した段階でlrが最大値になります。
# 1epochのminibatchの数は後述のパラメータで大きく変わるので、変更し忘れないように注意

# %%
## epoch=10で再度やってみる
# !fairseq-train data91 \
    --save-dir checkpoints/kftt.ja-en/epoch10/ \
    --arch lstm --share-decoder-input-output-embed \
    --optimizer adam --adam-betas '(0.9, 0.98)' --clip-norm 0.0 \
    --lr 5e-4 --lr-scheduler inverse_sqrt --warmup-updates 4000 \
    --dropout 0.3 --weight-decay 0.0001 \
    --criterion label_smoothed_cross_entropy --label-smoothing 0.1 \
    --max-tokens 4096 \
    --max-epoch 10 \
    --eval-bleu \
    --eval-bleu-detok moses \
    --eval-bleu-remove-bpe \
    --eval-bleu-print-samples \
    --best-checkpoint-metric bleu --maximize-best-checkpoint-metric
# Out:
# 2021-07-19 12:37:45 | INFO | fairseq_cli.train | Namespace(adam_betas='(0.9, 0.98)', adam_eps=1e-08, adaptive_softmax_cutoff='10000,50000,200000', all_gather_list_size=16384, arch='lstm', batch_size=None, batch_size_valid=None, best_checkpoint_metric='bleu', bf16=False, bpe=None, broadcast_buffers=False, bucket_cap_mb=25, checkpoint_shard_count=1, checkpoint_suffix='', clip_norm=0.0, cpu=False, criterion='label_smoothed_cross_entropy', curriculum=0, data='data91', data_buffer_size=10, dataset_impl=None, ddp_backend='c10d', decoder_attention='1', decoder_dropout_in=0.3, decoder_dropout_out=0.3, decoder_embed_dim=512, decoder_embed_path=None, decoder_freeze_embed=False, decoder_hidden_size=512, decoder_layers=1, decoder_out_embed_dim=512, device_id=0, disable_validation=False, distributed_backend='nccl', distributed_init_method=None, distributed_no_spawn=False, distributed_num_procs=0, distributed_port=-1, distributed_rank=0, distributed_world_size=1, distributed_wrapper='DDP', dropout=0.3, empty_cache_freq=0, encoder_bidirectional=False, encoder_dropout_in=0.3, encoder_dropout_out=0.3, encoder_embed_dim=512, encoder_embed_path=None, encoder_freeze_embed=False, encoder_hidden_size=512, encoder_layers=1, eval_bleu=True, eval_bleu_args=None, eval_bleu_detok='moses', eval_bleu_detok_args=None, eval_bleu_print_samples=True, eval_bleu_remove_bpe='@@ ', eval_tokenized_bleu=False, fast_stat_sync=False, find_unused_parameters=False, finetune_from_model=None, fix_batches_to_gpus=False, fixed_validation_seed=None, fp16=False, fp16_init_scale=128, fp16_no_flatten_grads=False, fp16_scale_tolerance=0.0, fp16_scale_window=None, gen_subset='test', ignore_prefix_size=0, keep_best_checkpoints=-1, keep_interval_updates=-1, keep_last_epochs=-1, label_smoothing=0.1, left_pad_source='True', left_pad_target='False', load_alignments=False, localsgd_frequency=3, log_format=None, log_interval=100, lr=[0.0005], lr_scheduler='inverse_sqrt', max_epoch=10, max_source_positions=1024, max_target_positions=1024, max_tokens=4096, max_tokens_valid=4096, max_update=0, maximize_best_checkpoint_metric=True, memory_efficient_bf16=False, memory_efficient_fp16=False, min_loss_scale=0.0001, min_lr=-1.0, model_parallel_size=1, no_epoch_checkpoints=False, no_last_checkpoints=False, no_progress_bar=False, no_save=False, no_save_optimizer_state=False, no_seed_provided=False, nprocs_per_node=1, num_batch_buckets=0, num_shards=1, num_workers=1, optimizer='adam', optimizer_overrides='{}', patience=-1, pipeline_balance=None, pipeline_checkpoint='never', pipeline_chunks=0, pipeline_decoder_balance=None, pipeline_decoder_devices=None, pipeline_devices=None, pipeline_encoder_balance=None, pipeline_encoder_devices=None, pipeline_model_parallel=False, profile=False, quantization_config_path=None, report_accuracy=False, required_batch_size_multiple=8, required_seq_len_multiple=1, reset_dataloader=False, reset_lr_scheduler=False, reset_meters=False, reset_optimizer=False, restore_file='checkpoint_last.pt', save_dir='checkpoints/kftt.ja-en/epoch10/', save_interval=1, save_interval_updates=0, scoring='bleu', seed=1, sentence_avg=False, shard_id=0, share_all_embeddings=False, share_decoder_input_output_embed=True, skip_invalid_size_inputs_valid_test=False, slowmo_algorithm='LocalSGD', slowmo_momentum=None, source_lang=None, stop_time_hours=0, target_lang=None, task='translation', tensorboard_logdir=None, threshold_loss_scale=None, tokenizer=None, tpu=False, train_subset='train', truncate_source=False, update_freq=[1], upsample_primary=1, use_bmuf=False, use_old_adam=False, user_dir=None, valid_subset='valid', validate_after_updates=0, validate_interval=1, validate_interval_updates=0, warmup_init_lr=-1, warmup_updates=4000, weight_decay=0.0001, zero_sharding='none')
# 2021-07-19 12:37:45 | INFO | fairseq.tasks.translation | [ja] dictionary: 51584 types
# 2021-07-19 12:37:45 | INFO | fairseq.tasks.translation | [en] dictionary: 58552 types
# 2021-07-19 12:37:45 | INFO | fairseq.data.data_utils | loaded 1166 examples from: data91/valid.ja-en.ja
# 2021-07-19 12:37:45 | INFO | fairseq.data.data_utils | loaded 1166 examples from: data91/valid.ja-en.en
# 2021-07-19 12:37:45 | INFO | fairseq.tasks.translation | data91 valid ja-en 1166 examples
# 2021-07-19 12:37:46 | INFO | fairseq_cli.train | LSTMModel(
#   (encoder): LSTMEncoder(
#     (dropout_in_module): FairseqDropout()
#     (dropout_out_module): FairseqDropout()
#     (embed_tokens): Embedding(51584, 512, padding_idx=1)
#     (lstm): LSTM(512, 512)
#   )
#   (decoder): LSTMDecoder(
#     (dropout_in_module): FairseqDropout()
#     (dropout_out_module): FairseqDropout()
#     (embed_tokens): Embedding(58552, 512, padding_idx=1)
#     (layers): ModuleList(
#       (0): LSTMCell(1024, 512)
#     )
#     (attention): AttentionLayer(
#       (input_proj): Linear(in_features=512, out_features=512, bias=False)
#       (output_proj): Linear(in_features=1024, out_features=512, bias=False)
#     )
#   )
# )
# 2021-07-19 12:37:46 | INFO | fairseq_cli.train | task: translation (TranslationTask)
# 2021-07-19 12:37:46 | INFO | fairseq_cli.train | model: lstm (LSTMModel)
# 2021-07-19 12:37:46 | INFO | fairseq_cli.train | criterion: label_smoothed_cross_entropy (LabelSmoothedCrossEntropyCriterion)
# 2021-07-19 12:37:46 | INFO | fairseq_cli.train | num. model params: 62427136 (num. trained: 62427136)
# 2021-07-19 12:37:46 | INFO | fairseq.trainer | detected shared parameter: decoder.attention.input_proj.bias <- decoder.attention.output_proj.bias
# 2021-07-19 12:37:46 | INFO | fairseq_cli.train | training on 1 devices (GPUs/TPUs)
# 2021-07-19 12:37:46 | INFO | fairseq_cli.train | max tokens per GPU = 4096 and max sentences per GPU = None
# 2021-07-19 12:37:46 | INFO | fairseq.trainer | no existing checkpoint found checkpoints/kftt.ja-en/epoch10/checkpoint_last.pt
# 2021-07-19 12:37:46 | INFO | fairseq.trainer | loading train data for epoch 1
# 2021-07-19 12:37:47 | INFO | fairseq.data.data_utils | loaded 440288 examples from: data91/train.ja-en.ja
# 2021-07-19 12:37:47 | INFO | fairseq.data.data_utils | loaded 440288 examples from: data91/train.ja-en.en
# 2021-07-19 12:37:47 | INFO | fairseq.tasks.translation | data91 train ja-en 440288 examples
# epoch 001:   0% 0/3599 [00:00<?, ?it/s]2021-07-19 12:37:47 | INFO | fairseq.trainer | begin training epoch 1
# epoch 001:   6% 205/3599 [59:42<15:52:57, 16.85s/it, loss=14.553, nll_loss=14.366, ppl=21118.3, wps=189.6, ups=0.06, wpb=3286.5, bsz=113.8, num_updates=200, lr=2.5e-05, gnorm=1.343, train_wall=1732, wall=3501]

# %% [markdown]
# ## 92. 機械翻訳モデルの適用
# 91で学習したニューラル機械翻訳モデルを用い，与えられた（任意の）日本語の文を英語に翻訳するプログラムを実装せよ．

# %% [markdown]
# fairseq-interactiveを使って，翻訳する．
#
# https://fairseq.readthedocs.io/en/latest/command_line_tools.html#fairseq-interactive

# %%
# !fairseq-interactive data91/ \
  --path checkpoints/kftt.ja-en/checkpoint_best.pt \
  < /content/kftt-data-1.0/data/tok/kyoto-test.ja \
  > 92.out
# Out:
# 256

# %% [markdown]
# ## 93. BLEUスコアの計測
# 91で学習したニューラル機械翻訳モデルの品質を調べるため，評価データにおけるBLEUスコアを測定せよ．

# %%
# !fairseq-score --sys 92.out --ref data-bin/kftt-data-1.0/data/tok/kyoto-test.en

# %% [markdown]
# ## 94. ビーム探索
# 91で学習したニューラル機械翻訳モデルで翻訳文をデコードする際に，ビーム探索を導入せよ．ビーム幅を1から100くらいまで適当に変化させながら，開発セット上のBLEUスコアの変化をプロットせよ．

# %% [markdown]
# ## 95. サブワード化
# トークンの単位を単語や形態素からサブワードに変更し，91-94の実験を再度実施せよ．

# %% [markdown]
# ## 96. 学習過程の可視化
# Tensorboardなどのツールを用い，ニューラル機械翻訳モデルが学習されていく過程を可視化せよ．可視化する項目としては，学習データにおける損失関数の値とBLEUスコア，開発データにおける損失関数の値とBLEUスコアなどを採用せよ．

# %% [markdown]
# ## 97. ハイパー・パラメータの調整
# ニューラルネットワークのモデルや，そのハイパーパラメータを変更しつつ，開発データにおけるBLEUスコアが最大となるモデルとハイパーパラメータを求めよ．
